# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv('/Users/ksenapavlucenko/PROG/PYT/StudentsPerformance.csv')

# %%
students_performance.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_performance.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
students_performance.size
# Out:
# 8000

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.iloc[0:3, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree

# %%
students_performance.iloc[[0, 3, 6], [2]]
# Out:
#   parental level of education
# 0           bachelor's degree
# 3          associate's degree
# 6                some college

# %%
students_performance.iloc[0:1, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree

# %%
stud =  students_performance.iloc[[0, 1, 3]]

# %%
students_performance_with_names = students_performance.iloc[[0, 3, 4, 7, 8]]

# %%
students_performance_with_names.index = ["Cersei", "Tywin", "Gregor", "Joffrey", "Ilyn Payne"]

# %%
students_performance_with_names
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilyn Payne    male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %%
students_performance_with_names.loc[['Cersei', 'Joffrey'],['gender', "writing score"]]
# Out:
#          gender  writing score
# Cersei   female             74
# Joffrey    male             39

# %%
my_series_1 = pd.Series([1, 2, 3], index = ["Cersei", "Tywin", "Gregor"])
my_series_2 = pd.Series([4, 5, 6], index = ["Cersei", "Tywin", "Gregor"])

# %%
pd.DataFrame({'col_name_1':my_series_1, 'col_name_2':my_series_2})
# Out:
#         col_name_1  col_name_2
# Cersei           1           4
# Tywin            2           5
# Gregor           3           6

# %%
students_performance.iloc[0:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
students_performance.iloc[:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
students_performance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
students_performance.shape
# Out:
# (1000, 8)

# %%
students_performance.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j6/15_nmndj4db7x9677htylfhr0000gn/T/ipykernel_90967/804495129.py in ?()
# ----> 1 students_performance.get_dtype_counts()
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
students_performance.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
titanic = pd.read_csv('/Users/ksenapavlucenko/PROG/PYT/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
float_columns = titanic.select_dtypes(include=['float64'])
float_columns.shape
# Out:
# (891, 2)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
students_performance.loc[students_performance.gender == 'female', ['gender', 'writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %%
students_performance['writing score']
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %%
writing_score_mean_value = students_performance['writing score'].mean()

# %%
writing_score_mean_value
# Out:
# np.float64(68.054)

# %%
students_performance.loc[students_performance['writing score'] > writing_score_mean_value]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
query = (students_performance['writing score'] > writing_score_mean_value) & (students_performance.gender == 'female')

# %%
students_performance.loc[query].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
fr = (students_performance['lunch'] == 'free/reduced')

# %%
students_performance.loc[fr]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
len(students_performance.loc[fr].head())
# Out:
# 5

# %%
a = (len(students_performance.loc[fr]))/(len(students_performance))

# %%
a
# Out:
# 0.355

# %%
len(students_performance)
# Out:
# 1000

# %%
free = (students_performance['lunch'] == 'free/reduced')
df_free = students_performance.loc[free]
df_free
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
stan = (students_performance['lunch'] == 'standard')
df_stan = students_performance.loc[stan]
df_stan
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
df_free['math score'].mean()
# Out:
# np.float64(58.92112676056338)

# %%
df_free['reading score'].mean()
# Out:
# np.float64(64.65352112676057)

# %%
df_free['writing score'].mean()
# Out:
# np.float64(63.02253521126761)

# %%
df_stan['math score'].mean()
# Out:
# np.float64(70.03410852713178)

# %%
df_stan['reading score'].mean()
# Out:
# np.float64(71.65426356589147)

# %%
df_stan['writing score'].mean()
# Out:
# np.float64(70.8232558139535)

# %%
df_free['math score'].var()
# Out:
# np.float64(229.82426991326489)

# %%
df_free['reading score'].var()
# Out:
# np.float64(221.87113869658629)

# %%
df_free['writing score'].var()
# Out:
# np.float64(238.20288056019737)

# %%
df_stan['math score'].var()
# Out:
# np.float64(186.41808946025327)

# %%
df_stan['reading score'].var()
# Out:
# np.float64(191.28556020992824)

# %%
df_stan['writing score'].var()
# Out:
# np.float64(205.62088689874338)

# %%
students_performance = students_performance \
    .rename(columns = {'parental level of education' : 'parental_level_of_education', 
                       'test preparation course' : 'test_preparation_course',
                       'math score' : 'math_score',
                       'reading score' : 'reading_score',
                       'writing score' : 'writing_score'})

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.query('Pclass > 2')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
students_performance.query('writing_score >74')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
tt  = 67

# %%
students_performance.query('writing_score > @tt')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
score_columns = [i for i in list(students_performance) if 'score' in i]

# %%
df_score_columns = students_performance[score_columns].head()

# %%
df_score_columns.mean()
# Out:
# math_score       70.8
# reading_score    78.4
# writing_score    74.8
# dtype: float64

# %%
students_performance.filter(like = "score")
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
s_p = students_performance

# %%
s_p
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
s_p_groupby_gender = students_performance.groupby('gender')
s_p_groupby_gender.mean('score')
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
students_performance.groupby('gender', as_index=False)\
    .aggregate({'math_score' : 'mean', 'writing_score' : 'mean'})\
    .rename({'math_score' : 'mean_math_score', 'writing_score' : 'mean_writing_score'}, axis = 0)
# Out:
#    gender  mean_math_score  mean_writing_score
# 0  female        63.633205           72.467181
# 1    male        68.728216           63.311203

# %%
students_performance['writing_score']
# Out:
#      writing_score
# 0               74
# 1               88
# 2               93
# 3               44
# 4               75
# ..             ...
# 995             95
# 996             55
# 997             65
# 998             77
# 999             86
#
# [1000 rows x 1 columns]

# %%
students_performance.groupby(['gender', 'race/ethnicity' ], as_index=False)\
    .aggregate({'math_score' : 'mean', 'writing_score' : 'mean'})\
    .rename({'math_score' : 'mean_math_score', 'writing_score' : 'mean_writing_score'}, axis = 0)
# Out:
#    gender race/ethnicity  math_score  writing_score
# 0  female        group A   58.527778      67.861111
# 1  female        group B   61.403846      70.048077
# 2  female        group C   62.033333      71.777778
# 3  female        group D   65.248062      75.023256
# 4  female        group E   70.811594      75.536232
# 5    male        group A   63.735849      59.150943
# 6    male        group B   65.930233      60.220930
# 7    male        group C   67.611511      62.712230
# 8    male        group D   69.413534      65.413534
# 9    male        group E   76.746479      67.394366

# %%
students_performances.groupby(['gender', 'race/ethnicity']).math_score.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 students_performances.groupby(['gender', 'race/ethnicity']).math_score.nunique()
#
# NameError: name 'students_performances' is not defined

# %%
s_p.sort_values(['gender', 'math_score'], ascending = False).groupby('gender').head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 s_p.sort_values(['gender', 'math_score'], ascending = False).groupby('gender').head(5)
#
# AttributeError: 'function' object has no attribute 'sort_values'

# %%
s_p['total_score'] = s_p.math_score + s_p.reading_score + s_p.writing_score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 s_p['total_score'] = s_p.math_score + s_p.reading_score + s_p.writing_score
#
# AttributeError: 'function' object has no attribute 'math_score'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 s_p.head(5)
#
# AttributeError: 'function' object has no attribute 'head'

# %%
s_p = s_p.assign(total_score_log = np.log(s_p.total_score))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 s_p = s_p.assign(total_score_log = np.log(s_p.total_score))
#
# AttributeError: 'function' object has no attribute 'assign'
